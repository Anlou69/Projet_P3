# %%
import pandas as pd

# Lecture du fichier :
df = pd.read_excel(r"C:\Users\messa\OneDrive - ALTYNO\WCS Projet 3\Input\2020_Equipements.xlsx", sheet_name='2020_Equipements', usecols='A:GM')

# Enregistrement du fichier en csv :
path02=r"C:\Users\messa\OneDrive - ALTYNO\WCS Projet 3\Input\2020_Equipements_T.csv"
df.to_csv(path02,sep=",")

df
# Out:
#        DepCode              DepLib ComInsee                 ComLib  \
# 0           01                 Ain    01001  Abergement-Clémenciat
# 1           01                 Ain    01001  Abergement-Clémenciat
# 2           01                 Ain    01001  Abergement-Clémenciat
# 3           01                 Ain    01001  Abergement-Clémenciat
# 4           01                 Ain    01001  Abergement-Clémenciat
# ...        ...                 ...      ...                    ...
# 318032     988  Nouvelle-Calédonie    98833                Kouaoua
# 318033     988  Nouvelle-Calédonie    98833                Kouaoua
# 318034     988  Nouvelle-Calédonie    98833                Kouaoua
# 318035     988  Nouvelle-Calédonie    98833                Kouaoua
# 318036     988  Nouvelle-Calédonie    98833                Kouaoua
#
#        InsNumeroInstall                           InsNom    EquipementId  \
# 0            I010010003  Salle Polyvalente - Boulodromes  E001I010010003
# ...
